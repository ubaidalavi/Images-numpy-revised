# %%
import PIL
from PIL import Image
import os
import fnmatch
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %%
def plti(im, h=5, **kwargs):
    y = im.shape[0]
    x = im.shape[1]
    w = (y/x) * h
    plt.figure(figsize=(w,h))
    plt.imshow(im,interpolation='none', **kwargs)
    plt.axis("off")

# %%
rootDir = 'images'
for dirName, subdirList, fileList in os.walk(rootDir):
    print('Found directory: %s' % dirName)

for fname in fileList:
    if fnmatch.fnmatch(fname, '*.jpg'):
        print('Found image: %s' % fname)

x_data = []

for fname in fileList:
    if fnmatch.fnmatch(fname, '*.jpg'):
        img = Image.open(str(rootDir + '/' + fname))
        new_width  = 200
        new_height = 200
        img = img.resize((new_width, new_height), Image.ANTIALIAS)
        x_data.append(np.array(img))


print(np.array(x_data).shape)
for img in x_data:
    print(img.shape)
    plti(img)
# Out:
# Found directory: images
# Found image: download (1).jpg
# Found image: download (10).jpg
# Found image: download (11).jpg
# Found image: download (2).jpg
# Found image: download (3).jpg
# Found image: download (4).jpg
# Found image: download (5).jpg
# Found image: download (6).jpg
# Found image: download (7).jpg
# Found image: download (8).jpg
# Found image: download (9).jpg
# Found image: download.jpg
# Found image: images (1).jpg
# Found image: images (2).jpg
# Found image: images (3).jpg
# Found image: images (4).jpg
# Found image: images (5).jpg
# Found image: images (6).jpg
# Found image: images.jpg
# Found image: plane.jpg
# (20, 200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)
